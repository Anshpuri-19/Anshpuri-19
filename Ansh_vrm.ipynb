# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshpuri-19/Anshpuri-19/blob/main/Ansh_vrm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('test_healthcare_data.csv')

# %%
plt.figure(figsize=(8,5))
sns.histplot(df['age'], kde=True,color='skyblue',bins=20)

plt.title('Age Distribution of Tested Patients', fontsize=14)
plt.xlabel('Age(Years)',fontsize=12)
plt.ylabel('count',fontsize=12)
# Out:
# Text(0, 0.5, 'count')

# %%
plt.figure(figsize=(10,8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap', fontsize=14)
plt.show()

# %%
import os
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
sns.set_theme(style="whitegrid")
print("ML libraries import sucessfully!")
# Out:
# ML libraries import sucessfully!
